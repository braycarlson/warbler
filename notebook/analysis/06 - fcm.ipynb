# %% [markdown]
# # EDA for FCM Clustering

# %%
# Reload the notebook if an external file is updated
# %load_ext autoreload
# %autoreload 2

import os
import sys

from pathlib import Path

path = (
    Path
    .cwd()
    .parent
    .parent
    .joinpath('warbler')
    .as_posix()
)

os.chdir(path)
sys.path.append(path)

# %%
import matplotlib.pyplot as plt
import scienceplots
import seaborn as sns

from constant import PROJECTION
from datatype.dataset import Dataset
from matplotlib import pyplot as plt

# %%
plt.style.use('science')

# %%
dataset = Dataset('segment')
dataframe = dataset.load()

# %%
folders = dataframe.folder.unique()

# %% [markdown]
# # 2D

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Amount of Segments per 2D Cluster')

sns.barplot(
    x=dataframe.fcm_label_2d.value_counts().index,
    y=dataframe.fcm_label_2d.value_counts(), 
    orient='v'
)

ax.set_xlabel('2D FCM Label')
ax.set_ylabel('Segment')

filename = 'fcm_amount_of_segments_per_2d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Duration of Each 2D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_2d').duration.mean().index,
    y=dataframe.groupby('fcm_label_2d').duration.mean(), 
    orient='v'
)

ax.set_xlabel('2D FCM Label')
ax.set_ylabel('Duration (s)')

filename = 'fcm_mean_duration_of_each_2d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Minimum Frequency of Each 2D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_2d').minimum.mean().index,
    y=dataframe.groupby('fcm_label_2d').minimum.mean(), 
    orient='v'
)

ax.set_xlabel('2D FCM Label')
ax.set_ylabel('Frequency (Hz)')

filename = 'fcm_mean_minimum_frequency_of_each_2d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Maximum Frequency of Each 2D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_2d').maximum.mean().index,
    y=dataframe.groupby('fcm_label_2d').maximum.mean(), 
    orient='v'
)

ax.set_xlabel('2D FCM Label')
ax.set_ylabel('Frequency (Hz)')

filename = 'fcm_mean_maximum_frequency_of_each_2d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %% [markdown]
# # 3D

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Amount of Segments per 3D Cluster')

sns.barplot(
    x=dataframe.fcm_label_3d.value_counts().index,
    y=dataframe.fcm_label_3d.value_counts(), 
    orient='v'
)

ax.set_xlabel('3D FCM Label')
ax.set_ylabel('Segment')

filename = 'fcm_amount_of_segments_per_3d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Duration of Each 3D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_3d').duration.mean().index,
    y=dataframe.groupby('fcm_label_3d').duration.mean(), 
    orient='v'
)

ax.set_xlabel('3D FCM Label')
ax.set_ylabel('Duration (s)')

filename = 'fcm_mean_duration_of_each_3d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Minimum Frequency of Each 3D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_3d').minimum.mean().index,
    y=dataframe.groupby('fcm_label_3d').minimum.mean(), 
    orient='v'
)

ax.set_xlabel('3D FCM Label')
ax.set_ylabel('Frequency (Hz)')

filename = 'fcm_mean_minimum_frequency_of_each_3d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()

# %%
fig, ax = plt.subplots(
    figsize=(18, 12)
)

ax.set_title('Mean Maximum Frequency of Each 3D Cluster')

sns.barplot(
    x=dataframe.groupby('fcm_label_3d').maximum.mean().index,
    y=dataframe.groupby('fcm_label_3d').maximum.mean(), 
    orient='v'
)

ax.set_xlabel('3D FCM Label')
ax.set_ylabel('Frequency (Hz)')

filename = 'fcm_mean_maximum_frequency_of_each_3d_cluster.png'
path = PROJECTION.joinpath(filename)

plt.savefig(
    path,
    bbox_inches='tight',
    dpi=300,
    format='png'
)

plt.show()
plt.close()
